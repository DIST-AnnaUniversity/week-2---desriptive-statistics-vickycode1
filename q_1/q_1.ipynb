# %% [markdown]
# # The miles per gallon rating for 30 cars are shown below (lowest to highest).
# 19,19,19,20,21,21,25,25,25,26,26,28,29,31,31,32,32,33,34,35,36,37,37,38,38,38,38,41,43,43

# %%
import stemgraphic 
import matplotlib.pyplot as plt
data=[ 19, 19, 19, 20, 21, 21, 25, 25, 25, 26, 26, 28, 29,31, 31, 32, 32, 33, 34, 35, 36, 37, 37, 38, 38, 38, 38, 41, 43, 43]
stems=[1,1,1,2,2,2,2,2,2,2,2,2,2,3,3,3,3,3,3,3,3,3,3,3,3,3,3,4,4,4]
plt.ylabel('Data')   
plt.xlabel('stems')   
plt.stem(stems, data)
stemgraphic.stem_graphic(data, scale = 10)
# Out:
# (<Figure size 540x126 with 1 Axes>, <Axes:>)
