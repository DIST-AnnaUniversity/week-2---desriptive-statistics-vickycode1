# %% [markdown]
# q_7_2

# %%
import pandas as p
data = p.read_csv("India-Tourism-Statistics-2021-Table-2.1.1.csv")
import matplotlib.pyplot as plt
data
# Out:
#     Year  FTAs in India (in Million)  \
# 0   1981                        1.28
# 1   1991                        1.68
# 2   2001                        2.54
# 3   2002                        2.38
# 4   2003                        2.73
# 5   2004                        3.46
# 6   2005                        3.92
# 7   2006                        4.45
# 8   2007                        5.08
# 9   2008                        5.28
# 10  2009                        5.17
# 11  2010                        5.78
# 12  2011                        6.31
# 13  2012                        6.58
# 14  2013                        6.97
# 15  2014                        7.68
# 16  2015                        8.03
# 17  2016                        8.80
# 18  2017                       10.04
# 19  2018                       10.56
# 20  2019                       10.93
# 21  2020                        2.74
#
#     Percentage (%) change over previous year  \
# 0                                        2.0
# 1                                       -1.7
# 2                                       -4.2
# 3                                       -6.0
# 4                                       14.3
# 5                                       26.8
# 6                                       13.3
# 7                                       13.5
# 8                                       14.3
# 9                                        4.0
# 10                                      -2.2
# 11                                      11.8
# 12                                       9.2
# 13                                       4.3
# 14                                       5.9
# 15                                      10.2
# 16                                       4.5
# 17                                       9.7
# 18                                      14.0
# 19                                       5.2
# 20                                       3.5
# 21                                     -74.9
#
#     NRIs arrivals in India (in million)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                 5.43
# 16                                 5.74
# 17                                 6.22
# 18                                 6.77
# 19                                 6.87
# 20                                 6.98
# 21                                 3.59
#
#     ercentage (%) change over the previous year  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          5.7
# 17                                          8.5
# 18                                          8.8
# 19                                          1.4
# 20                                          1.7
# 21                                        -48.6
#
#     International Tourist Arrivals in India  (in million)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                              13.11
# 16                                              13.76
# 17                                              15.03
# 18                                              16.81
# 19                                              17.42
# 20                                              17.91
# 21                                               6.33
#
#     Percentage (%) change over the previous year  Unnamed: 7  Unnamed: 8  \
# 0                                            NaN         NaN         NaN
# 1                                            NaN         NaN         NaN
# 2                                            NaN         NaN         NaN
# 3                                            NaN         NaN         NaN
# 4                                            NaN         NaN         NaN
# 5                                            NaN         NaN         NaN
# 6                                            NaN         NaN         NaN
# 7                                            NaN         NaN         NaN
# 8                                            NaN         NaN         NaN
# 9                                            NaN         NaN         NaN
# 10                                           NaN         NaN         NaN
# 11                                           NaN         NaN         NaN
# 12                                           NaN         NaN         NaN
# 13                                           NaN         NaN         NaN
# 14                                           NaN         NaN         NaN
# 15                                           NaN         NaN         NaN
# 16                                           5.0         NaN         NaN
# 17                                           9.2         NaN         NaN
# 18                                          11.8         NaN         NaN
# 19                                           3.7         NaN         NaN
# 20                                           2.8         NaN         NaN
# 21                                         -64.7         NaN         NaN
#
#     Unnamed: 9  Unnamed: 10
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
# 10         NaN          NaN
# 11         NaN          NaN
# 12         NaN          NaN
# 13         NaN          NaN
# 14         NaN          NaN
# 15         NaN          NaN
# 16         NaN          NaN
# 17         NaN          NaN
# 18         NaN          NaN
# 19         NaN          NaN
# 20         NaN          NaN
# 21         NaN          NaN

# %% [markdown]
# Boxplot

# %%
plt.boxplot(data['Year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f3d2641c1d0>,
#   <matplotlib.lines.Line2D at 0x7f3d2641c710>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3d2641cc50>,
#   <matplotlib.lines.Line2D at 0x7f3d263a41d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3d26407b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3d263a4750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3d264071d0>],
#  'means': []}
