# %% [markdown]
# q_7_3

# %%
import pandas as p
data = p.read_csv("India-Tourism-Statistics-2021-Table-2.1.1.csv")
import matplotlib.pyplot as plt
data
# Out:
#     Year  FTAs in India (in Million)  \
# 0   1981                        1.28
# 1   1991                        1.68
# 2   2001                        2.54
# 3   2002                        2.38
# 4   2003                        2.73
# 5   2004                        3.46
# 6   2005                        3.92
# 7   2006                        4.45
# 8   2007                        5.08
# 9   2008                        5.28
# 10  2009                        5.17
# 11  2010                        5.78
# 12  2011                        6.31
# 13  2012                        6.58
# 14  2013                        6.97
# 15  2014                        7.68
# 16  2015                        8.03
# 17  2016                        8.80
# 18  2017                       10.04
# 19  2018                       10.56
# 20  2019                       10.93
# 21  2020                        2.74
#
#     Percentage (%) change over previous year  \
# 0                                        2.0
# ...

# %% [markdown]
# Outlier Detection

# %%
plt.boxplot(data['Year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f3924f04550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f3924f04fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3924f6ff50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3924f0dad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3924f6f4d0>],
#  'means': []}

# %% [markdown]
# Outlier Removal

# %%
import numpy as np
lowerbound = np.percentile(data['Year'],25)
lowerbound
# Out:
# 2004.25

# %%
plt.boxplot(data[data['Year']>lowerbound]['Year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f39249f0510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f39249f0f90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3924a66fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f39249f7a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f39249f7fd0>],
#  'means': []}

# %%
data = data[data['Year']>lowerbound]
data.shape
# Out:
# (16, 11)
